# %% [markdown]
# # Аспектный анализ тональности текстов: используем возможности fasttext

# %%
# Если Вы запускаете ноутбук на colab или kaggle,
# выполните следующие строчки, чтобы подгрузить библиотеку dlnlputils:

# !git clone https://github.com/Samsung-IT-Academy/stepik-dl-nlp.git && pip install -r stepik-dl-nlp/requirements.txt
# import sys; sys.path.append('./stepik-dl-nlp')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

torch.manual_seed(1)

# %% [markdown]
# ## BIO-тэггинг для обучения модели

# %%
from dlnlputils.sentiment_utils import parse_xml_aspect, show_markup,prepare_data, generate_markup

# %%
from nltk.tokenize import RegexpTokenizer

word_tokenizer = RegexpTokenizer('\w+|\$[\d\.]+|\S+')

# %%
# Если Вы запускаете ноутбук на colab или kaggle, добавьте в начало пути ./stepik-dl-nlp
xml_train = 'datasets/sentirueval2015/SentiRuEval_car_markup_train.xml'
xml_test  = 'datasets/sentirueval2015/SentiRuEval_car_markup_test.xml'

# %%
texts_w_aspect_spans = parse_xml_aspect(xml_train)
texts_w_aspect_spans = [(text.lower(),spans) for text, spans in texts_w_aspect_spans]
training_data        = prepare_data(texts_w_aspect_spans, word_tokenizer.tokenize)

texts_w_aspect_spans = parse_xml_aspect(xml_test)
texts_w_aspect_spans = [(text.lower(),spans) for text, spans in texts_w_aspect_spans]
test_data            = prepare_data(texts_w_aspect_spans, word_tokenizer.tokenize)

# %%
len(training_data), len(test_data)
# Out:
# (2210, 1922)

# %%
test_recipe, test_tags = training_data[400]

text, spans = generate_markup(test_recipe, test_tags) 

show_markup(text, spans)
# Out:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">все так чисто ,<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">опрятно<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, светло и тепло , что я сразу же очутился в своей тарелке .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>

# %% [markdown]
# ## Статистика по тэгам

# %%
from collections import Counter
from collections import defaultdict

def form_vocabulary_and_tagset(words_w_tags):
    dictionary = defaultdict(Counter)
    for words,tags in words_w_tags: 
        for word, tag in zip(words, tags):
            dictionary[tag].update([word])      
    return dictionary, set(dictionary.keys())

# %%
word_counter, labels = form_vocabulary_and_tagset(training_data)

# %%
for label in labels:
    num_words = len(word_counter[label])
    print(f'{num_words}\tin {label}')
# Out:
# 236	in B-Whole
# 284	in I-Comfort
# 300	in I-Reliability
# 60	in B-Safety
# 189	in B-Appearance
# 97	in I-Costs
# 4933	in Other
# 464	in B-Reliability
# 169	in B-Costs
# 49	in I-Safety
# 478	in B-Comfort
# 584	in B-Driveability
# 200	in I-Whole
# 393	in I-Driveability
# 103	in I-Appearance

# %%
word_counter['I-Comfort'].most_common()#[-1]
# Out:
# [('в', 29),
#  ('салоне', 17),
#  ('места', 15),
#  ('сиденья', 14),
#  ('багажник', 12),
#  ('сидений', 10),
#  ('салона', 9),
#  ('на', 8),
#  ('для', 6),
#  ('сидения', 5),
#  ('багажника', 5),
#  ('с', 5),
#  ('и', 5),
#  ('комплектации', 5),
#  ('не', 5),
#  ('автомобиля', 4),
#  ('задние', 4),
#  ('управления', 4),
#  ('салон', 4),
#  ('автомобиле', 3),
#  ('тесно', 3),
#  ('отделение', 3),
#  ('передач', 3),
#  ('фар', 3),
#  ('стекло', 3),
#  ('хватает', 3),
#  ('приборов', 3),
#  ('ног', 3),
#  ('двери', 2),
#  ('пластик', 2),
#  ('авто', 2),
#  ('машины', 2),
#  ('колонка', 2),
#  ('все', 2),
#  ('пассажиров', 2),
#  ('панели', 2),
#  ('диване', 2),
#  ('обслуживании', 2),
#  ('заднем', 2),
#  ('водителя', 2),
#  ('от', 2),
#  ('панель', 2),
#  ('эксплуатации', 2),
#  ('универсал', 2),
#  ('-контроль', 2),
#  ('передних', 2),
#  ('потолок', 2),
#  ('достаточно', 2),
#  ('магнитолу', 2),
#  ('удобно', 2),
#  ('системы', 2),
#  ('сидениях', 2),
#  ('арок', 2),
#  ('chery', 2),
#  ('qq6', 2),
#  ('1', 2),
#  ('.1', 2),
#  ('стучит', 2),
#  ('безопасности', 2),
#  ('"космо"', 1),
#  ('руссифицированный', 1),
#  ('удобные', 1),
#  ('колонке', 1),
#  ('всяких', 1),
#  ('опций', 1),
#  ('шумы', 1),
#  ('логане', 1),
#  ('бояться', 1),
#  ('за', 1),
#  ('усталость', 1),
#  ('болела', 1),
#  ('focus', 1),
#  ('2', 1),
#  ('седан', 1),
#  ('автомат', 1),
#  ('уно', 1),
#  ('больше', 1),
#  ('руле', 1),
#  ('подлокотник', 1),
#  (')', 1),
#  ('заднего', 1),
#  ('вида', 1),
#  ('спортивный', 1),
#  ('болид', 1),
#  ('пластика', 1),
#  ('экран', 1),
#  ('бизнес', 1),
#  ('-класс', 1),
#  ('открывать', 1),
#  ('окна', 1),
#  ('полка', 1),
#  ('акустики', 1),
#  ('двигатель', 1),
#  ('зад', 1),
#  ('диваном', 1),
#  ('подлокотником', 1),
#  ('свет', 1),
#  ('топливного', 1),
#  ('бака', 1),
#  ('компьютере', 1),
#  ('-проигрывателе', 1),
#  ('кпп', 1),
#  ('тесноты', 1),
#  ('мультимедийный', 1),
#  ('плеер', 1),
#  ('тихо', 1),
#  ('диванчик', 1),
#  ('только', 1),
#  ('задний', 1),
#  ('дива', 1),
#  ('пакетам', 1),
#  ('поясница', 1),
#  ('-ноги', 1),
#  ('зеркал', 1),
#  ('запаска', 1),
#  ('кнопок', 1),
#  ('легкостью', 1),
#  ('поместиться', 1),
#  ('переднего', 1),
#  ('пассажира', 1),
#  ('положение', 1),
#  ('прогревается', 1),
#  ('температуры', 1),
#  ('нагрева', 1),
#  ('салазках', 1),
#  ('ужасно', 1),
#  ('части', 1),
#  ('хайса', 1),
#  ('люк', 1),
#  ('кондиционера', 1),
#  ('нам', 1),
#  ('мест', 1),
#  ('субары', 1),
#  ('огромной', 1),
#  ('баранкой', 1),
#  ('своих', 1),
#  ('местах', 1),
#  ('неудобств', 1),
#  ('появлялись', 1),
#  ('скрипы', 1),
#  ('часть', 1),
#  ('пространства', 1),
#  ('подогревает', 1),
#  ('зонный', 1),
#  ('климат', 1),
#  ('расположены', 1),
#  ('бардачке', 1),
#  ('оркестр', 1),
#  ('правой', 1),
#  ('панеле', 1),
#  ('подсветкой', 1),
#  ('приносит', 1),
#  ('дискомфорта', 1),
#  ('что', 1),
#  ('вмещается', 1),
#  ('долго', 1),
#  ('отличается', 1),
#  ('просторностью', 1),
#  ('коленки', 1),
#  ('спина', 1),
#  ('лихвой', 1),
#  ('хватит', 1),
#  ('совсем', 1),
#  ('комфортно', 1),
#  ('багаж', 1),
#  ('создает', 1),
#  ('раздражающих', 1),
#  ('звуков', 1),
#  ('бензином', 1),
#  ('включить', 1),
#  ('печку', 1),
#  ('машина', 1),
#  ('дверки', 1),
#  ('кнопки', 1),
#  ('переключения', 1),
#  ('система', 1),
#  ('гарнитурой', 1),
#  ('планка', 1),
#  ('под', 1),
#  ('рукой', 1),
#  ('навязчиво', 1),
#  ('опель', 1),
#  ('автомагнитола', 1),
#  ('водить', 1),
#  ('регулируются', 1),
#  ('комплектацию', 1),
#  ('фары', 1),
#  ('кожа', 1),
#  ('внутри', 1),
#  ('холодно', 1),
#  ('ноги', 1),
#  ('s', 1),
#  ('магнитола', 1),
#  ('сd', 1),
#  ('диски', 1),
#  ('стекла', 1),
#  ('компьютер', 1),
#  ('сидеть', 1),
#  ('греет', 1),
#  ('орет', 1),
#  ('ремонте', 1),
#  ('дверь', 1),
#  ('руля', 1),
#  ('управляется', 1),
#  ('тормоза', 1),
#  ('-подъёмники', 1),
#  ('свободно', 1),
#  ('мягко', 1),
#  ('сиденье', 1),
#  ('магнитолой', 1),
#  ('зеркала', 1),
#  ('маленький', 1),
#  ('контроль', 1),
#  ('жарко', 1),
#  ('холодный', 1),
#  ('воздух', 1),
#  ('замерзают', 1),
#  ('тепловой', 1),
#  ('удар', 1),
#  ('арки', 1),
#  ('pioneer', 1),
#  ('аудио', 1),
#  ('припарковаться', 1),
#  ('кресло', 1),
#  ('управлять', 1),
#  ('шумов', 1),
#  ('сидении', 1),
#  ('кресел', 1),
#  ('задних', 1),
#  ('мало', 1),
#  ('довольно', 1),
#  ('мал', 1),
#  ('как', 1),
#  ('болтается', 1),
#  ('бензин', 1),
#  ('баке', 1),
#  ('колесных', 1),
#  ('отсеке', 1),
#  ('тахометра', 1),
#  ('упираюсь', 1),
#  ('так', 1),
#  ('много', 1),
#  ('мульимедиа', 1),
#  ('климатом', 1),
#  ('мелочей', 1),
#  ('плпстиком', 1),
#  ('поддержка', 1),
#  ('со', 1),
#  ('двора', 1),
#  ('шума', 1),
#  ('вибраций', 1),
#  ('ваши', 1),
#  ('позвоночники', 1),
#  ('размер', 1),
#  ('дисплей', 1),
#  ('обогревом', 1),
#  ('"калины"', 1),
#  ('при', 1),
#  ('вождении', 1),
#  ('чистится', 1),
#  ('всех', 1),
#  ('вещей', 1),
#  ('есть', 1),
#  ('место', 1),
#  ('автомагнитолы', 1),
#  ('небольшой', 1),
#  ('-контроля', 1),
#  ('гремит', 1),
#  ('корпуса', 1),
#  ('автомобилю', 1),
#  ('дверей', 1),
#  ('полная', 1),
#  ('тишина', 1),
#  ('kangoo', 1),
#  ('удобны', 1),
#  ('ремни', 1),
#  ('присутствует', 1),
#  ('помещается', 1),
#  ('поддержки', 1),
#  ('спины', 1),
#  ('круиз', 1),
#  ('контороли', 1),
#  ('багажного', 1),
#  ('отдела', 1)]

# %%
class TagConverter():
    def __init__(self, tags):
        self.idx_to_tag  = sorted(tags)
        self.tag_to_idx  = {tag:idx for idx,tag in enumerate(self.idx_to_tag)}
        
    def tags_to_index(self, words):
        return torch.tensor([self.tag_to_idx[w] for w in words], dtype=torch.long)
    
    def indices_to_tags(self, indices):
        return [self.idx_to_tag[i] for i in indices]

# %%
tag_converter = TagConverter(labels)

# %%
test_recipe, test_tags = training_data[321]

# оригинал
text, spans = generate_markup(test_recipe, test_tags) 
show_markup(text, spans)

# кодируем только тэги:
encoded_tags = tag_converter.tags_to_index(test_tags)
print(encoded_tags)
print()

# декодируем тэги:
decoded_tags = tag_converter.indices_to_tags(encoded_tags)

text, spans = generate_markup(test_recipe, decoded_tags) 
show_markup(text, spans)
# Out:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">автомобиль<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">принадлежит дяде .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# tensor([ 6, 14, 14, 14])
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">автомобиль<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">принадлежит дяде .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>

# %% [markdown]
# ## fastText: забираем функции embedding слоя

# %%
import zipfile
import gensim
import wget

# %%
# model_url = 'http://vectors.nlpl.eu/repository/11/187.zip'
# wget.download(model_url)

# %% [markdown]
# #### модель fasttext: редкие и  выдуманные слова

# %%
# with zipfile.ZipFile('187.zip', 'r') as zip_ref:
#     zip_ref.extractall('datasets/187/')
    # Colab:
    # zip_ref.extractall('./stepik-dl-nlp/datasets/187/')

# %%
w2v_model = gensim.models.KeyedVectors.load('datasets/187/model.model')

# Colab:
# w2v_model = gensim.models.KeyedVectors.load('./stepik-dl-nlp/datasets/187/model.model')

# %%
words = ['тачаночка', 'двиганчик', 'ковервертолет']

for word in words:
    print(word)

    for i in w2v_model.most_similar(positive=[word], topn=10):
        nearest_word      = i[0]
        cosine_similarity = i[1]
        print(nearest_word, cosine_similarity)
    print('\n')
# Out:
# тачаночка
# тачанка 0.7318679094314575
# тачанк 0.6545170545578003
# бричка 0.627240777015686
# двуколка 0.610139012336731
# тачка 0.5886926054954529
# бараночка 0.5879709720611572
# паночка 0.573016881942749
# эмка 0.5701597929000854
# саничка 0.565357506275177
# каретка 0.5643386244773865
#
#
# двиганчик
# движка 0.4994381070137024
# танчик 0.4963422417640686
# двигай 0.4941864609718323
# двигатели 0.48835229873657227
# движа 0.4803929924964905
# двигун 0.46693849563598633
# движок 0.4630592465400696
# моторчик 0.45433372259140015
# шарк 0.4522787034511566
# движ 0.452262818813324
#
#
# ковервертолет
# вертолет 0.743363618850708
# ковер-самолет 0.6644095778465271
# вертолетная 0.6616967916488647
# вертолетчика 0.6364192962646484
# вертолёт 0.6328296065330505
# самолет 0.6245843768119812
# ковре-самолет 0.6201825141906738
# вертолетчик 0.6189783811569214
# гидросамолет 0.6109312176704407
# вертолетный 0.6071040630340576

# %% [markdown]
# Создадим конвертер слов в векторы fasttext:

# %%
class WordConverter:
    def __init__(self, w2v_model):
        self.w2v_model = w2v_model

    def convert(self, words):
        embeddings = [self.w2v_model.get_vector(word) for word in words]
        embeddings = torch.FloatTensor(embeddings)
        return embeddings

# %%
word_converter = WordConverter(w2v_model)

words,_ = training_data[333]
vectors = word_converter.convert(words)

vectors.shape
# Out:
# C:\Users\Роман\AppData\Local\Temp\ipykernel_3172\1159978501.py:7: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:233.)
#   embeddings = torch.FloatTensor(embeddings)
# torch.Size([27, 300])

# %% [markdown]
# ##  LSTM: теперь без embedding слоя

# %%
EMBEDDING_DIM = 300
HIDDEN_DIM    = 32
TAGSET_SIZE   = len(tag_converter.tag_to_idx)

# %%
class LSTMTagger(nn.Module):
    def __init__(self, embedding_dim, hidden_dim, output_dim, word_converter):
        super(LSTMTagger, self).__init__()
        tagset_size = len(tag_converter.tag_to_idx)
        
        self.word_converter = word_converter
        self.lstm           = nn.LSTM(embedding_dim, hidden_dim, bidirectional=True)
        self.hidden2tag     = nn.Linear(2*hidden_dim, output_dim)

    def forward(self, words):
        embeds      = self.word_converter.convert(words)
        lstm_out, _ = self.lstm(embeds.view(len(words), 1, -1))
        tag_space   = self.hidden2tag(lstm_out.view(len(words), -1))
        tag_scores  = F.log_softmax(tag_space, dim=1)
        return tag_scores
    
    def predict_tags(self, words):
        with torch.no_grad():
            tags_pred = model(words).numpy()
            tags_pred = np.argmax(tags_pred, axis=1)  
        return tags_pred

# %%
for label in labels:
    num_words = len(word_counter[label])
    print(f'{num_words}\tin {label}')
# Out:
# 236	in B-Whole
# 284	in I-Comfort
# 300	in I-Reliability
# 60	in B-Safety
# 189	in B-Appearance
# 97	in I-Costs
# 4933	in Other
# 464	in B-Reliability
# 169	in B-Costs
# 49	in I-Safety
# 478	in B-Comfort
# 584	in B-Driveability
# 200	in I-Whole
# 393	in I-Driveability
# 103	in I-Appearance

# %%
from collections import Counter
from pprint import pprint

tag_counter = Counter()
for label in labels:
    tag_counter[label] = len(word_counter[label])
        
pprint(tag_counter.most_common())


class_weights = torch.ones(15)
class_divs    = torch.ones(15)

for tag, inv_weight in tag_counter.most_common():
    tag_idx             = tag_converter.tags_to_index([tag])
    class_divs[tag_idx] = inv_weight
    
norm       = torch.norm(class_divs, p=2, dim=0).detach()
class_divs = class_divs.div(norm.expand_as(class_divs))

class_weights /= class_divs

print(class_weights.detach())
# Out:
# [('Other', 4933),
#  ('B-Driveability', 584),
#  ('B-Comfort', 478),
#  ('B-Reliability', 464),
#  ('I-Driveability', 393),
#  ('I-Reliability', 300),
#  ('I-Comfort', 284),
#  ('B-Whole', 236),
#  ('I-Whole', 200),
#  ('B-Appearance', 189),
#  ('B-Costs', 169),
#  ('I-Appearance', 103),
#  ('I-Costs', 97),
#  ('B-Safety', 60),
#  ('I-Safety', 49)]
# tensor([ 26.7865,  10.5913,  29.9565,   8.6689,  10.9109,  84.3775,  21.4519,
#          49.1519,  17.8262,  52.1923,  12.8821,  16.8755, 103.3194,  25.3132,
#           1.0263])

# %%
model         = LSTMTagger(EMBEDDING_DIM, HIDDEN_DIM, TAGSET_SIZE, word_converter)
loss_function = nn.NLLLoss(class_weights) 
optimizer     = optim.SGD(model.parameters(), lr=0.1)

# %%
from livelossplot import PlotLosses

liveplot = PlotLosses()

for epoch in range(5): 
    for i, (recipe, tags) in enumerate(training_data):
        
        model.zero_grad()
        
        tag_predicted = model(recipe) # <- теперь передаем предложение, а не список индексов слов
        tag_ground    = tag_converter.tags_to_index(tags) 
        
        
        loss = loss_function(tag_predicted, tag_ground)
        loss.backward()
        optimizer.step()
        
        if i % 100 == 0:
            liveplot.update({'negative log likelihood loss': loss.detach()})
            liveplot.draw()
# Out:
# negative log likelihood loss
# 	negative log likelihood loss 	 (min:    0.008, max:    4.235, cur:    0.315)

# %%
def predict_tags(model, recipe):
    encoded_tags   = model.predict_tags(recipe)      # предсказанные тэги (номера)
    decoded_tags   = tag_converter.indices_to_tags(encoded_tags) # номер тэга -> тэг
    return decoded_tags

# %%
for i in range(0,10):

    recipe, tags = test_data[np.random.randint(0,1000)]
    
    tags_pred    = predict_tags(model, recipe)

    print('истинные тэги:')
    text, spans = generate_markup(recipe, tags) 
    show_markup(text, spans)

    print('предсказанные тэги:')
    text, spans = generate_markup(recipe, tags_pred) 

    show_markup(text, spans)
    print()
# Out:
# истинные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">заводится<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">без проблем даже при большой температуре .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# предсказанные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">заводится<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">без проблем даже при<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">большой<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">температуре<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">.<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# истинные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">да это<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">что надо ! жаль что<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">дорогая<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Costs</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">но зато престижная ! шикарный<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">салон<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Appearance</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, оболденный<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">внешний вид<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Appearance</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, конструкторы посторались на славу , такая<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">сейчас не уступает к примеру<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">мерседесу<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">либо<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">бмв<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, только даже плюс у неё в отличии от других<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">машин расход<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">всё того же злочастного топлива ! зато есть один минус эта<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">машина<span style="vertical-align: middle;  ...
# предсказанные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">да это<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">что надо ! жаль что<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">дорогая<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Costs</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">но зато престижная !<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">шикарный салон<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Appearance</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">,<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">оболденный внешний вид , конструкторы посторались на<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Appearance</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">славу , такая<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">сейчас не<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">уступает<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">к примеру<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">мерседесу<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">либо<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">бмв<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, только даже плюс у неё в отличии от других<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">машин<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Costs< ...
# истинные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">расход бензина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">не велик .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# предсказанные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">расход бензина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">не<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">велик .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# истинные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">нравится в нем все даже то что он и<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">не комфортный<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">и это все исправляется собственными руками .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# предсказанные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">нравится в нем все даже то что он и не<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">комфортный<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">и это все исправляется собственными<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">руками<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">.<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# истинные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">я был удивлен<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">вместительностью<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, и<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">большим размером багажника<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, порадовало .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# предсказанные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">я был удивлен<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">вместительностью<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, и большим<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">размером багажника<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, порадовало .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# истинные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">только вот не надо сравнивать с<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">иномарками<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">за 700 ,900 тысяч .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# предсказанные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">только вот не надо сравнивать с<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">иномарками<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">за 700 ,900 тысяч .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# истинные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">начну с того что покупают его люди прежде всего в<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">целях экономии<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Costs</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, думая о том , что с покупкой<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">иномарки<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">они забудут все неприятности присущие отечественному автопрому , однако это не так .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# предсказанные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">начну с того что покупают его люди прежде всего в целях<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">экономии<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Costs</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, думая о том , что с<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">покупкой<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Costs</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">иномарки<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">они забудут все неприятности присущие<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">отечественному автопрому<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, однако это не так .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# истинные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">а больше всего мне нравится , что я могу как сзади , так и спереди<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">вытянуть ноги<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">спокойно и наслаждаться поездкой ) она тяжеловата , может быть поэтому очень<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">ровно едет<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, чувствуешь себя в ней как на море в корабле .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# предсказанные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">а больше всего мне нравится , что я могу как сзади , так и<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">спереди<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">вытянуть<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">ноги спокойно<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">и наслаждаться поездкой ) она тяжеловата , может быть поэтому очень<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">ровно едет<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">,<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">чувствуешь<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">себя в ней как на море в корабле .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# истинные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">сегоня хочу рассказать вам о своем знакомстве с данным<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">автомобилем<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span></div>
# предсказанные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">сегоня хочу рассказать вам о своем знакомстве с<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">данным автомобилем<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span></div>
# истинные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">сэкономлено было на всём .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# предсказанные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">сэкономлено<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Costs</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">было на всём .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>

# %%
from dlnlputils.sentiment_utils import plot_confusion_matrix

# %%
y_pred = []
y_true = []

for sentence, tags in test_data:
    y_pred += predict_tags(model, sentence)
    y_true += tags

# %%
ordered_tags = [
 'Other',
 'B-Whole',
 'I-Whole',
 'B-Driveability',
 'I-Driveability',
 'B-Appearance',
 'I-Appearance',
 'B-Reliability',
 'I-Reliability',
 'B-Comfort',
 'I-Comfort',
 'B-Costs',
 'I-Costs',
 'B-Safety',
 'I-Safety']

# %%
plot_confusion_matrix(y_true, y_pred, classes=ordered_tags, normalize=True, 
                      title='Нормализованная матрица ошибок')
plt.show()
