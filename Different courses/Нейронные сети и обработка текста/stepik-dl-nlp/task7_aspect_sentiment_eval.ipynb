# %% [markdown]
# # Аспектный анализ тональности текстов

# %% [markdown]
# * [1] https://github.com/nlpub/pymystem3
# * [2] SentiRuEval2015
# * [3] https://rusvectores.org/ru/models/

# %%
# Если Вы запускаете ноутбук на colab или kaggle,
# выполните следующие строчки, чтобы подгрузить библиотеку dlnlputils:

# !git clone https://github.com/Samsung-IT-Academy/stepik-dl-nlp.git && pip install -r stepik-dl-nlp/requirements.txt
# import sys; sys.path.append('./stepik-dl-nlp')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

torch.manual_seed(1)

# %% [markdown]
# ## Оригинальная разметка

# %%
# Если Вы запускаете ноутбук на colab или kaggle, добавьте в начало пути ./stepik-dl-nlp
xml_sentiments = 'datasets/sentirueval2015/SentiRuEval_car_markup_train.xml'

# %%
from dlnlputils.sentiment_utils import parse_xml_sentiment, parse_xml_aspect, show_markup

# %%
xml_sentiments
# Out:
# 'datasets/sentirueval2015/SentiRuEval_car_markup_train.xml'

# %% [markdown]
# тексты с разметкой аспектов и тональностей:

# %%
texts_w_sentiment_spans = parse_xml_sentiment(xml_sentiments)
texts_w_aspect_spans    = parse_xml_aspect(xml_sentiments)

# %%
amount = len(texts_w_sentiment_spans)

print('Загружено {} текстов с разметкой тональности\n'.format(amount))
# Out:
# Загружено 217 текстов с разметкой тональности

# %%
texts_w_sentiment_spans[0]
# Out:
# ('Недавно купил этот автомобиль. Авто отличное! Двигатель 2,5 литра, турбодизель. Прежний хозяин сказал при продаже, что масло не жрет, солярку тоже, летит как угорелая! Так оно и есть. 140 км/ч нормальная крейсерская скорость. Вообще немцы умеют делать автомобили. Дорогу держит отлично, так как достаточно широкая машина. Тормоза все дисковые. Главное передний привод, по сравнению с другими немецкими автомобилями. Такими как мерседес и бмв этого же класса. Места в автомобиле очень много. Не тесно даже, когда сидят пять взрослых человек. Багажное отделение тоже огромно. Влезла стиральная машина. По соотношению цена - качество, отличный автомобиль. Больше никогда не сяду за руль российского автомбиля! Всем рекомендую Ауди. ',
#  [(19, 29, 'neutral'),
#   (31, 35, 'positive'),
#   (46, 65, 'neutral'),
#   (67, 78, 'neutral'),
#   (125, 132, 'positive'),
#   (134, 141, 'positive'),
#   (148, 166, 'positive'),
#   (204, 224, 'positive'),
#   (252, 262, 'positive'),
#   (264, 277, 'positive'),
#   (306, 320, 'positive'),
#   (322, 329, 'neutral'),
#   (334, 342, 'neutral'),
#   (352, 367, 'neutral'),
#   (392, 414, 'positive'),
#   (427, 435, 'neutral'),
#   (438, 441, 'neutral'),
#   (459, 477, 'positive'),
#   (491, 499, 'positive'),
#   (541, 559, 'positive'),
#   (603, 630, 'positive'),
#   (641, 651, 'positive'),
#   (684, 705, 'negative'),
#   (723, 727, 'positive')])

# %%
texts_w_aspect_spans[0]
# Out:
# ('Недавно купил этот автомобиль. Авто отличное! Двигатель 2,5 литра, турбодизель. Прежний хозяин сказал при продаже, что масло не жрет, солярку тоже, летит как угорелая! Так оно и есть. 140 км/ч нормальная крейсерская скорость. Вообще немцы умеют делать автомобили. Дорогу держит отлично, так как достаточно широкая машина. Тормоза все дисковые. Главное передний привод, по сравнению с другими немецкими автомобилями. Такими как мерседес и бмв этого же класса. Места в автомобиле очень много. Не тесно даже, когда сидят пять взрослых человек. Багажное отделение тоже огромно. Влезла стиральная машина. По соотношению цена - качество, отличный автомобиль. Больше никогда не сяду за руль российского автомбиля! Всем рекомендую Ауди. ',
#  [(19, 29, 'Whole'),
#   (31, 35, 'Whole'),
#   (46, 65, 'Driveability'),
#   (67, 78, 'Driveability'),
#   (125, 132, 'Driveability'),
#   (134, 141, 'Driveability'),
#   (148, 166, 'Driveability'),
#   (204, 224, 'Driveability'),
#   (252, 262, 'Whole'),
#   (264, 277, 'Driveability'),
#   (306, 320, 'Driveability'),
#   (322, 329, 'Driveability'),
#   (334, 342, 'Driveability'),
#   (352, 367, 'Driveability'),
#   (392, 414, 'Driveability'),
#   (427, 435, 'Driveability'),
#   (438, 441, 'Driveability'),
#   (459, 477, 'Comfort'),
#   (491, 499, 'Comfort'),
#   (541, 559, 'Comfort'),
#   (603, 630, 'Costs'),
#   (641, 651, 'Costs'),
#   (684, 705, 'Whole'),
#   (723, 727, 'Whole')])

# %% [markdown]
# ##### выберем 2 текста, на которых будем рассматривать все примеры:

# %%
random_picks = [random.randint(0,amount-1) for _ in range(0,2)]

# %% [markdown]
# ####  тональность (sentiment)

# %%
for rand_i in random_picks:
    text, spans = texts_w_sentiment_spans[rand_i]
    
    print('Текст №:',rand_i)
    show_markup(text,spans)
# Out:
# Текст №: 96
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Очень <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">ходовая машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">positive</span></span>, <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">проедет везде<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">positive</span></span>, как на дачу так и по городу, <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">не дорогие<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">positive</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">запчасти<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">positive</span></span> найдутся практически везде, хороший <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">кузов<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">positive</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">мало гниет<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">positive</span></span>, в моем случае очень <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">выносливый мотор<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">positive</span></span>, загрузить машину можно полностью <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">едет как танк<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">positive</span></span>, загружал в нее 5 бревен, <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">удобный<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">positive</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">просторный<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">positive</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">салон<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">positive</span></span>, <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">дизайн автомобиля<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">positive</span></span> идеальный. Просто отличный <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">автомобиль<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">positive</span></span>, для повседневной езды, хоть и старый, неплохая <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">вместительность багажника<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">positive</span></span>, можно убрать <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">задние сидения<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">positive</span></span> и возить что нибудь, громадское </div>
# Текст №: 179
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">Peugeot 308<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">positive</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">positive</span></span> является зарубежным аналогом <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">отечественной Лада 2114<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">negative</span></span>, но намного лучшим аналогом, поскольку обладает <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">мотором<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">positive</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">по мощнее<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">positive</span></span> (112 <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">лошадок<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">neutral</span></span>)и по <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">экономичнее<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">positive</span></span> (в среднем 7-8 литров при <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">смешаном типе езди<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">neutral</span></span> ). Но есть и минусы, например: водитель тупо <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">не видит капота<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">negative</span></span>, <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">расстояние от передних колес до конца передней части<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">negative</span></span> довольно велико, из-за этого при <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">спуски с горки<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">negative</span></span> и <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">попадании в яму<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">negative</span></span> можно <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">зацепить передний бампер<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">negative</span></span>. Также <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">negative</span></span> не очень <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">вместительная<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">negative</span></span>, <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">места на задних сидениях мало<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">negative</span></span>, <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">багажник довольно мал<span style="vertical- ...

# %% [markdown]
# ####  Аспекты (aspects)

# %%
for rand_i in random_picks:
    text,spans = texts_w_aspect_spans[rand_i]
    
    print('Текст №:',rand_i)
    show_markup(text,spans)
# Out:
# Текст №: 96
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Очень <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">ходовая машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span>, <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">проедет везде<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span>, как на дачу так и по городу, <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">не дорогие<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Costs</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">запчасти<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Costs</span></span> найдутся практически везде, хороший <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">кузов<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">мало гниет<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span>, в моем случае очень <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">выносливый мотор<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span>, загрузить машину можно полностью <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">едет как танк<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span>, загружал в нее 5 бревен, <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">удобный<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">просторный<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">салон<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span>, <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">дизайн автомобиля<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Appearance</span></span> идеальный. Просто отличный <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">автомобиль<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span>, для повседневной езды, хоть и старый, неплохая <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">вместительность багажника<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span>, можно убрать <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">задние сидения<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> и возить что нибудь, громадское </div>
# Текст №: 179
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">Peugeot 308<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> является зарубежным аналогом <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">отечественной Лада 2114<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span>, но намного лучшим аналогом, поскольку обладает <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">мотором<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">по мощнее<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> (112 <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">лошадок<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span>)и по <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">экономичнее<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Costs</span></span> (в среднем 7-8 литров при <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">смешаном типе езди<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> ). Но есть и минусы, например: водитель тупо <span style="padding: 2px; border-radius: 4px; border: 1px solid #d1c4e9; background: #ede7f6">не видит капота<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #9575cd;">Safety</span></span>, <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">расстояние от передних колес до конца передней части<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> довольно велико, из-за этого при <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">спуски с горки<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> и <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">попадании в яму<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> можно <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">зацепить передний бампер<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span>. Также <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> не очень <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">вместительная<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span>, <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">места на задних сидениях мало<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span>, <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">багажник довольно мал<span s ...

# %% [markdown]
# ## BIO-тэги для обучения модели

# %%
from dlnlputils.sentiment_utils import fill_gaps, extract_BIO_tagged_tokens

# %%
for rand_i in random_picks:
    text, aspect_spans = texts_w_aspect_spans[rand_i]
    cover_spans       = fill_gaps(text, aspect_spans)
    
    print('Полное покрытие разметкой текста №:',rand_i) 
    show_markup(text, cover_spans)
# Out:
# Полное покрытие разметкой текста №: 96
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">Очень <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">ходовая машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">проедет везде<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, как на дачу так и по городу, <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">не дорогие<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Costs</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">запчасти<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Costs</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> найдутся практически везде, хороший <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">кузов<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">мало гниет<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, в моем случае очень <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">выносливый мотор<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, загрузить машину можно полностью <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">едет как танк<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, загружал в нее 5 бревен, <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">удобный<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d; ...
# Полное покрытие разметкой текста №: 179
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">Peugeot 308<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> является зарубежным аналогом <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">отечественной Лада 2114<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, но намного лучшим аналогом, поскольку обладает <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">мотором<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">по мощнее<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> (112 <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">лошадок<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">)и по <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">экономичнее<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Costs</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> (в среднем 7-8 литров при <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">смешаном типе езди<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> ). Но есть и минусы, например: водитель тупо <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d1c4e9; background: #ede7f6">не видит капота<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #9575cd;">Safety</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; co ...

# %% [markdown]
# ### Разбиение текста на предложения, а предложений - на слова.

# %%
from dlnlputils.sentiment_utils import regex_sentence_detector, sentence_spans,sentence_splitter

# %%
from nltk.tokenize import RegexpTokenizer

word_tokenizer = RegexpTokenizer('\w+|\$[\d\.]+|\S+')

# %%
for rand_i in random_picks:
    text, aspect_spans = texts_w_aspect_spans[rand_i]

    print('Разбиение на предложения и BIO токенизация текста №:',rand_i) 
    for sentence, spans in sentence_splitter(text, aspect_spans):

        cover_spans      = fill_gaps(sentence,spans)
        tokens_w_biotags = extract_BIO_tagged_tokens(sentence, 
                                                     cover_spans, 
                                                     word_tokenizer.tokenize)

        show_markup(sentence, cover_spans)
        print(tokens_w_biotags[:10],'\n')
# Out:
# Разбиение на предложения и BIO токенизация текста №: 96
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">Очень <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">ходовая машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">проедет везде<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, как на дачу так и по городу, <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">не дорогие<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Costs</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">запчасти<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Costs</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> найдутся практически везде, хороший <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">кузов<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">мало гниет<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, в моем случае очень <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">выносливый мотор<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, загрузить машину можно полностью <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">едет как танк<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, загружал в нее 5 бревен, <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">удобный<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d; ...
# [('Очень', 'Other'), ('ходовая', 'B-Whole'), ('машина', 'I-Whole'), (',', 'Other'), ('проедет', 'B-Driveability'), ('везде', 'I-Driveability'), (',', 'Other'), ('как', 'Other'), ('на', 'Other'), ('дачу', 'Other')]
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">Просто отличный <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">автомобиль<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, для повседневной езды, хоть и старый, неплохая <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">вместительность багажника<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, можно убрать <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">задние сидения<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> и возить что нибудь, громадское <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# [('Просто', 'Other'), ('отличный', 'Other'), ('автомобиль', 'B-Whole'), (',', 'Other'), ('для', 'Other'), ('повседневной', 'Other'), ('езды', 'Other'), (',', 'Other'), ('хоть', 'Other'), ('и', 'Other')]
#
# Разбиение на предложения и BIO токенизация текста №: 179
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">Peugeot 308<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> является зарубежным аналогом <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">отечественной Лада 2114<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, но намного лучшим аналогом, поскольку обладает <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">мотором<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">по мощнее<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> (112 <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">лошадок<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">)и по <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">экономичнее<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Costs</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> (в среднем 7-8 литров при <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">смешаном типе езди<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> ).<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# [('Peugeot', 'B-Whole'), ('308', 'I-Whole'), ('машина', 'B-Whole'), ('является', 'Other'), ('зарубежным', 'Other'), ('аналогом', 'Other'), ('отечественной', 'B-Whole'), ('Лада', 'I-Whole'), ('2114', 'I-Whole'), (',', 'Other')]
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">Но есть и минусы, например: водитель тупо <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d1c4e9; background: #ede7f6">не видит капота<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #9575cd;">Safety</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">расстояние от передних колес до конца передней части<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> довольно велико, из-за этого при <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">спуски с горки<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> и <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">попадании в яму<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> можно <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">зацепить передний бампер<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span>.</div>
# [('Но', 'Other'), ('есть', 'Other'), ('и', 'Other'), ('минусы', 'Other'), (',', 'Other'), ('например', 'Other'), (':', 'Other'), ('водитель', 'Other'), ('тупо', 'Other'), ('не', 'B-Safety')]
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">Также <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> не очень <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">вместительная<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">места на задних сидениях мало<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">багажник довольно мал<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d1c4e9; background: #ede7f6">обзор сзади мал<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #9575cd;">Safety</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> (это доставляет большие <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">неудобства<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> при <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">езде задом<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">).<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# [('Также', 'Other'), ('машина', 'B-Whole'), ('не', 'Other'), ('очень', 'Other'), ('вместительная', 'B-Comfort'), (',', 'Other'), ('места', 'B-Comfort'), ('на', 'I-Comfort'), ('задних', 'I-Comfort'), ('сидениях', 'I-Comfort')]
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Коробка автомат<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> слишком &quot;тупая&quot;, при нажатии на газ (при резком нажатии) слишком <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">долго &quot;думает<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">&quot;, также если пользоваться спортивным режимом то вже через несколько тис.<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# [('Коробка', 'B-Driveability'), ('автомат', 'I-Driveability'), ('слишком', 'Other'), ('"тупая",', 'Other'), ('при', 'Other'), ('нажатии', 'Other'), ('на', 'Other'), ('газ', 'Other'), ('(при', 'Other'), ('резком', 'Other')]
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">км.<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# [('км', 'Other'), ('.', 'Other')]
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">нужно <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">ремонтировать двигатель<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span>.</div>
# [('нужно', 'Other'), ('ремонтировать', 'B-Reliability'), ('двигатель', 'I-Reliability')]
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">Салон<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> собрат <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">качественно<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, но и здесь есть недостаток, а именно <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">слышно как болтается бензин в баке<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span>.</div>
# [('Салон', 'B-Reliability'), ('собрат', 'Other'), ('качественно', 'B-Reliability'), (',', 'Other'), ('но', 'Other'), ('и', 'Other'), ('здесь', 'Other'), ('есть', 'Other'), ('недостаток', 'Other'), (',', 'Other')]
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">Общее впечатление : Довольно <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">красивая<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Appearance</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9"> <span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Appearance</span></span><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, но есть и недостатки.<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# [('Общее', 'Other'), ('впечатление', 'Other'), (':', 'Other'), ('Довольно', 'Other'), ('красивая', 'B-Appearance'), ('машина', 'B-Appearance'), (',', 'Other'), ('но', 'Other'), ('есть', 'Other'), ('и', 'Other')]

# %% [markdown]
# ##  Подготовка данных для обучения:

# %%
from dlnlputils.sentiment_utils import prepare_data, form_vocabulary_and_tagset

# %%
# Если Вы запускаете ноутбук на colab или kaggle, добавьте в начало пути ./stepik-dl-nlp
xml_train = 'datasets/sentirueval2015/SentiRuEval_car_markup_train.xml'
xml_test  = 'datasets/sentirueval2015/SentiRuEval_car_markup_test.xml'

# %% [markdown]
# ### Токенизация:

# %%
texts_w_aspect_spans = parse_xml_aspect(xml_train)
training_data        = prepare_data(texts_w_aspect_spans, word_tokenizer.tokenize)

texts_w_aspect_spans = parse_xml_aspect(xml_test)
test_data            = prepare_data(texts_w_aspect_spans, word_tokenizer.tokenize)

# %% [markdown]
# #### разбиение на предложения дало нам столько коротких текстов:

# %%
len(training_data), len(test_data)
# Out:
# (2210, 1922)

# %%
all_data = training_data + test_data

# %%
vocabulary,labels = form_vocabulary_and_tagset(all_data)

# %%
labels
# Out:
# {'B-Appearance',
#  'B-Comfort',
#  'B-Costs',
#  'B-Driveability',
#  'B-Reliability',
#  'B-Safety',
#  'B-Whole',
#  'I-Appearance',
#  'I-Comfort',
#  'I-Costs',
#  'I-Driveability',
#  'I-Reliability',
#  'I-Safety',
#  'I-Whole',
#  'Other'}

# %% [markdown]
# #### а размер словаря:

# %%
len(vocabulary), len(labels)
# Out:
# (11333, 15)

# %% [markdown]
# #### индексация:

# %%
from dlnlputils.sentiment_utils import Converter, generate_markup

# %%
converter = Converter(vocabulary,labels)

# %%
test_recipe, test_tags = training_data[1211]

text, spans = generate_markup(test_recipe, test_tags) 

show_markup(text, spans)

encoded_recipe = converter.words_to_index(test_recipe)
encoded_tags   = converter.tags_to_index(test_tags)

print(encoded_recipe)
print(encoded_tags)
print()

decoded_recipe = converter.indices_to_words(encoded_recipe)
decoded_tags   = converter.indices_to_tags(encoded_tags)

text, spans = generate_markup(decoded_recipe, decoded_tags) 

show_markup(text, spans)
# Out:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">За первых три года не было<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">ни одной поломки<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, потом стали проявляться мелкие<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">неисправности<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">:<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">подшипник на полуоси<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">,<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">лампочки дальнего ближнего света<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">,<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">крестовины<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">,<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">аккумулятор<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">,<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">свечи<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span></div>
# tensor([ 1395,  7307, 10381,  3591,  6303,  2877,  6524,  6847,  7826,   289,
#          8063,  9912,  8648,  5768,  6381,   823,  7653,  6064,  7835,   289,
#          5435,  3739,  2737,  9234,   289,  5331,   289,  2540,   289,  9247])
# tensor([14, 14, 14, 14, 14, 14,  4, 11, 11, 14, 14, 14, 14, 14,  4, 14,  4, 11,
#         11, 14,  4, 11, 11, 11, 14,  4, 14,  4, 14,  4])
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">За первых три года не было<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">ни одной поломки<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, потом стали проявляться мелкие<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">неисправности<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">:<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">подшипник на полуоси<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">,<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">лампочки дальнего ближнего света<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">,<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">крестовины<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">,<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">аккумулятор<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">,<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">свечи<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span></div>

# %% [markdown]
# ### Нейросети

# %%
EMBEDDING_DIM = 300
HIDDEN_DIM    = 32
VOCAB_SIZE    = len(converter.word_to_idx)
TAGSET_SIZE   = len(converter.tag_to_idx)

# %% [markdown]
# ###  Предобученные векторы слов
#
# Алгоритм fastText обученный на корпусе Тайга, смотрите подробности на сайте: https://rusvectores.org/ru/models/

# %%
# !pip3 install wget

# %%
import zipfile
import gensim
# import wget

model_url = 'http://vectors.nlpl.eu/repository/11/187.zip'

model_file = 'datasets/' + model_url.split('/')[-1]
# wget.download(model_url, model_file)

# %%
w2v_model = gensim.models.KeyedVectors.load('datasets/187/model.model')

words = ['тачка', 'двигатель', 'ауди']

for word in words:
    #if word in w2v_model:
           
    for i in w2v_model.most_similar(positive=[word], topn=10):
        nearest_word      = i[0]
        cosine_similarity = i[1]
        print(nearest_word, cosine_similarity)
    print('\n')
    
    #else: print(word + ' is not present in the model')
# Out:
# жигулёнка 0.7488205432891846
# ишачка 0.7310285568237305
# грузовичка 0.7278668880462646
# жигулёнок 0.7127147912979126
# жигуленок 0.706432044506073
# тележка 0.6995413899421692
# мопед 0.6990943551063538
# сачка 0.6923120021820068
# катафалка 0.6904969811439514
# бричка 0.6855131387710571
#
#
# двигатели 0.9118232727050781
# гипердвигатель 0.8655393123626709
# электродвигатель 0.8446589708328247
# мотор 0.8106047511100769
# электромотор 0.8067886233329773
# авиадвигатель 0.7910490036010742
# движок 0.7793391346931458
# перводвигатель 0.7768319249153137
# двигательный 0.7394744157791138
# турбина 0.7326768636703491
#
#
# bmw 0.7961359620094299
# бмв 0.7914925813674927
# аудь 0.7911134958267212
# тойота 0.7723557353019714
# мерседес 0.7654416561126709
# mw 0.7585864067077637
# bmv 0.7522681951522827
# форд 0.7281615734100342
# тойот 0.7268385887145996
# лексус 0.7258473038673401

# %%
numpy_embeddings = np.zeros(shape=[VOCAB_SIZE, EMBEDDING_DIM],dtype=np.float32)

for word in vocabulary:
    #if word in w2v_model:
    vector = w2v_model.get_vector(word)
    index  = converter.words_to_index([word])
    numpy_embeddings[index] = vector
        
    #else: print(word + ' - такого слова нет в модели fasttext')
        
pretrained_embeddings = torch.FloatTensor(numpy_embeddings)
pretrained_embeddings.shape
# Out:
# torch.Size([11333, 300])

# %% [markdown]
# ### LSTM
#
# 1. Использует предобученные вектора слов и не изменяет их
# 2. Двунаправленная

# %%
class LSTMTagger(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, tagset_size, pretrained_embeddings):
        super(LSTMTagger, self).__init__()
        
        self.hidden_dim      = hidden_dim
        self.word_embeddings = nn.Embedding.from_pretrained(pretrained_embeddings, freeze=True)
        self.lstm            = nn.LSTM(embedding_dim, hidden_dim, bidirectional=True)
        self.hidden2tag      = nn.Linear(2*hidden_dim, tagset_size)

    def forward(self, words):
        embeds      = self.word_embeddings(words)
        lstm_out, _ = self.lstm(embeds.view(len(words), 1, -1))
        tag_space   = self.hidden2tag(lstm_out.view(len(words), -1))
        tag_scores  = F.log_softmax(tag_space, dim=1)
        
        return tag_scores
    
    def predict_tags(self, words):
        with torch.no_grad():
            tags_pred = model(words).numpy()
            tags_pred = np.argmax(tags_pred, axis=1)
            
        return tags_pred

# %% [markdown]
# ### Взвешеная функция потерь

# %%
from collections import Counter

tag_counter = Counter()
for _,tokens in training_data:
    for token in tokens:
        tag_counter[token]+=1
        
tag_counter.most_common()
# Out:
# [('Other', 23529),
#  ('B-Driveability', 1188),
#  ('B-Comfort', 1092),
#  ('I-Driveability', 773),
#  ('B-Reliability', 769),
#  ('B-Whole', 768),
#  ('I-Comfort', 480),
#  ('I-Reliability', 457),
#  ('B-Costs', 392),
#  ('B-Appearance', 354),
#  ('I-Whole', 310),
#  ('I-Costs', 177),
#  ('I-Appearance', 146),
#  ('B-Safety', 87),
#  ('I-Safety', 63)]

# %%
class_weights = torch.ones(15)
class_divs    = torch.ones(15)

for tag, inv_weight in tag_counter.most_common():
    tag_idx             = converter.tags_to_index([tag])
    class_divs[tag_idx] = inv_weight
    
print(class_divs)
    
norm       = torch.norm(class_divs, p=2, dim=0).detach()
class_divs = class_divs.div(norm.expand_as(class_divs))


class_weights /= class_divs


print(class_weights.detach())
# Out:
# tensor([  354.,  1092.,   392.,  1188.,   769.,    87.,   768.,   146.,   480.,
#           177.,   773.,   457.,    63.,   310., 23529.])
# tensor([ 66.7812,  21.6488,  60.3075,  19.8994,  30.7419, 271.7303,  30.7819,
#         161.9215,  49.2511, 133.5623,  30.5828,  51.7298, 375.2466,  76.2598,
#           1.0047])

# %%
model         = LSTMTagger(EMBEDDING_DIM, HIDDEN_DIM, VOCAB_SIZE, TAGSET_SIZE, pretrained_embeddings)
loss_function = nn.NLLLoss(class_weights) 
optimizer     = optim.SGD(model.parameters(), lr=0.1)

# %% [markdown]
# #### training

# %%
from livelossplot import PlotLosses

liveplot = PlotLosses()

for epoch in range(5): 
    for i, (recipe, tags) in enumerate(training_data):
        
        model.zero_grad()
        
        encoded_recipe = converter.words_to_index(recipe) # слово -> его номер в словаре 
        encoded_tags   = converter.tags_to_index(tags)    # тэг   -> его номер в списке тэгов
        tag_scores     = model(encoded_recipe)
        
        loss = loss_function(tag_scores, encoded_tags)
        loss.backward()
        optimizer.step()
        
        
        if i % 100 == 0:
            liveplot.update({'negative log likelihood loss': loss.detach()})
            liveplot.draw()
# Out:
# negative log likelihood loss
# 	negative log likelihood loss 	 (min:    0.009, max:    4.193, cur:    0.163)

# %%
def predict_tags(model, converter, recipe):
    
    encoded_recipe = converter.words_to_index(recipe)        # слово -> его номер в словаре

    encoded_tags   = model.predict_tags(encoded_recipe)      # предсказанные тэги (номера)

    decoded_tags   = converter.indices_to_tags(encoded_tags) # номер тэга -> тэг
    
    return decoded_tags

# %%
for i in range(0,10):

    recipe, tags = test_data[np.random.randint(0,1000)]
    
    tags_pred    = predict_tags(model, converter, recipe)

    print('истинные тэги:')
    text, spans = generate_markup(recipe, tags) 
    show_markup(text, spans)

    print('предсказанные тэги:')
    text, spans = generate_markup(recipe, tags_pred) 

    show_markup(text, spans)
    print()
# Out:
# истинные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">Вообще ,<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">под мой характер -<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">педаль газа<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">как сенсорная , только прикоснулся , она<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">рвет с места<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, а<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">тормоз<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">надо немного больше нажать .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# предсказанные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">Вообще ,<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">под мой характер -<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">педаль газа<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">как<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">сенсорная<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, только прикоснулся , она<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">рвет<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">с<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">места<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">,<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">а тормоз<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">Driveability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">надо немного больше нажать .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# истинные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">Машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">довольно таки хороша (до нее была<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">приора<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">).<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# предсказанные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">Машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">довольно таки хороша (до нее была<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">приора<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">).<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# истинные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">В общем , все очень<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">простенько<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">(даже в сравнении с<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">вазами<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">).<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# предсказанные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">В общем , все очень простенько (даже в сравнении с<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">вазами<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">).<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# истинные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">Климат у нас на севере очень суровый поэтому<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">работала постоянно .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# предсказанные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">Климат<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">у нас на севере очень<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">суровый<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">поэтому<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">машина<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">работала<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">постоянно .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# истинные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">В<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">Тойоту Старлет вмещается<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">пять , шесть человек , но не большой комплекции .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# предсказанные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">В Тойоту Старлет вмещается пять , шесть человек , но не<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">большой комплекции<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">.<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# истинные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">Только вот не надо сравнивать с<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">иномарками<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">за 700 ,900 тысяч .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# предсказанные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">Только вот не надо сравнивать с<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">иномарками<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">за 700 ,900 тысяч .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# истинные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">Думаю , это не проблема .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# предсказанные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">Думаю , это не проблема .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# истинные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">В общем , ребят , подведу итог , не берите себе данный<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">автомобиль<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">! Общее впечатление : Отечественный<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">автомобиль -погремушка<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">Comfort</span></span></div>
# предсказанные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">В общем , ребят , подведу<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">итог<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">, не берите себе<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">данный автомобиль<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">! Общее впечатление :<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">Отечественный автомобиль<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">-погремушка<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">Reliability</span></span></div>
# истинные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">Началось .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# предсказанные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">Началось .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span></div>
# истинные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">Общее впечатление : Отличный<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">эконом -автомобиль<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span></div>
# предсказанные тэги:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">Общее впечатление : Отличный<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">Other</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">эконом<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Costs</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">-автомобиль<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">Whole</span></span></div>

# %% [markdown]
# ### Статистика

# %% [markdown]
# ##### 1.  Количество верно предсказанных тэгов:

# %%
from dlnlputils.sentiment_utils import tag_statistics

# %%
total_correct, total_tags = tag_statistics(model, converter, test_data)


print('Статистика верно предсказанных тэгов:\n')

for tag in total_tags.keys():
    print('для {}:'.format(tag))
    print('  корректно:\t', total_correct[tag])
    print('      всего:\t',   total_tags[tag])
    print('% корректно:\t', 100 * (total_correct[tag] / float(total_tags[tag])))
    print()

print('----------')
print('в итоге:')
print('  корректно:\t', sum(total_correct.values()))
print('      всего:\t', sum(total_tags.values()))
print('% корректно:\t', 100 * (sum(total_correct.values()) / sum(total_tags.values())))
# Out:
# Статистика верно предсказанных тэгов:
#
# для Other:
#   корректно:	 16228
#       всего:	 19922
# % корректно:	 81.45768497138842
#
# для B-Whole:
#   корректно:	 519
#       всего:	 673
# % корректно:	 77.11738484398218
#
# для B-Driveability:
#   корректно:	 484
#       всего:	 1066
# % корректно:	 45.40337711069418
#
# для I-Driveability:
#   корректно:	 306
#       всего:	 711
# % корректно:	 43.037974683544306
#
# для B-Appearance:
#   корректно:	 156
#       всего:	 275
# % корректно:	 56.72727272727273
#
# для I-Appearance:
#   корректно:	 37
#       всего:	 100
# % корректно:	 37.0
#
# для B-Reliability:
#   корректно:	 329
#       всего:	 809
# % корректно:	 40.66749072929542
#
# для I-Whole:
#   корректно:	 107
#       всего:	 213
# % корректно:	 50.23474178403756
#
# для B-Comfort:
#   корректно:	 589
#       всего:	 1067
# % корректно:	 55.201499531396436
#
# для I-Comfort:
#   корректно:	 198
#       всего:	 497
# % корректно:	 39.839034205231385
#
# для I-Reliability:
#   корректно:	 128
#       всего:	 475
# % корректно:	 26.94736842105263
#
# для B-Costs:
#   корректно:	 215
#       всего:	 389
# % корректно:	 55.26992287917738
#
# для I-Costs:
#   корректно:	 28
#       всего:	 127
# % корректно:	 22.04724409448819
#
# для B-Safety:
#   корректно:	 25
#       всего:	 96
# % корректно:	 26.041666666666668
#
# для I-Safety:
#   корректно:	 8
#       всего:	 71
# % корректно:	 11.267605633802818
#
# ----------
# в итоге:
#   корректно:	 19357
#       всего:	 26491
# % корректно:	 73.07009927900042

# %% [markdown]
# ##### 2.  Количество верно предсказанных тэгов в виде матрицы ошибок:

# %%
from dlnlputils.sentiment_utils import plot_confusion_matrix

# %%
y_pred = []
y_true = []

for sentence, tags in test_data:
    y_pred += predict_tags(model, converter, sentence)
    y_true += tags

# %%
plot_confusion_matrix(y_true, y_pred, classes=list(total_tags.keys()), title='Матрица ошибок')

plt.show()

# %%
plot_confusion_matrix(y_true, y_pred, classes=list(total_tags.keys()), normalize=True, 
                      title='Нормализованная матрица ошибок')

plt.show()
